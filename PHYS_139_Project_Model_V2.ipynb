# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from IPython.display import FileLink
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
from sklearn import linear_model
import xgboost as xgb
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from xgboost import XGBRFRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error, make_scorer, mean_squared_error, r2_score
from sklearn.model_selection import (
    cross_val_score,
    cross_val_predict, 
    ShuffleSplit, 
    GridSearchCV,
    KFold,
    train_test_split,
)
from sklearn.neighbors import kneighbors_graph
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis,
    QuadraticDiscriminantAnalysis,
)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GATConv, GraphSAGE, SAGEConv
from torch_geometric.data import Data, DataLoader
import optuna

# %% [markdown]
# # Download the Data

# %%
supercond_df = pd.read_csv('/home/ckasemtantikul/cleaned_supercond_df.csv')
final_design_matrix_supercond = pd.read_csv('/home/ckasemtantikul/final_design_matrix_supercond.csv')
df = pd.merge(supercond_df, final_design_matrix_supercond, left_index=True, right_index=True, how='left')
df = df.dropna()

# %%
X = df.drop(['chemical_formula','Tc','composition','elements','Category','num_elements','stoichiometry'], axis=1)
y = df[['Tc']]
display(X)
display(y)
# Out:
#       Average AtomicRadius  Average AtomicVolume  Average AtomicWeight  \
# 0                 1.097143          10637.113673             57.873967
# 1                 1.093929          10636.906970             56.808817
# 2                 1.047143          10635.250819             67.135606
# 3                 1.094643          10637.075533             56.330499
# 4                 1.094286          10637.036937             56.424486
# ...                    ...                   ...                   ...
# 8833              1.196667             26.523951             80.111022
# 8834              1.203333             26.765795             79.993582
# 8835              1.210000             27.007639             79.876142
# 8836              1.216667             27.249483             79.758702
# 8837              1.223333             27.491327             79.641262
#
#       Average BoilingT  Average CovalentRadius  Average Density  \
# 0          1542.185714              115.885714      2974.616571
# 1          1531.728571              115.457143      2955.759429
# 2          1514.857143              110.800000      3905.930857
# 3          1519.428571              115.571429      2899.123714
# 4          1517.542857              115.401429      2926.630857
# ...                ...                     ...              ...
# 8833       1944.373667              130.100000      5445.850000
# 8834       1904.340333              130.500000      5330.216667
# 8835       1864.307000              130.900000      5214.583333
# 8836       1824.273667              131.300000      5098.950000
# 8837       1784.240333              131.700000      4983.316667
#
#       Average ElectronAffinity  Average Electronegativity  \
# 0                   110.470357                   2.546929
# 1                   110.279214                   2.548214
# 2                   110.741429                   2.589143
# 3                   109.180857                   2.544571
# 4                   109.875429                   2.546757
# ...                        ...                        ...
# 8833                 74.800000                   1.962833
# 8834                 76.466667                   1.961833
# 8835                 78.133333                   1.960833
# 8836                 79.800000                   1.959833
# 8837                 81.466667                   1.958833
#
#       Average FirstIonizationEnergy  Average HeatCapacityMass  ...  \
# 0                         10.471085                  0.635479  ...
# 1                         10.481439                  0.637664  ...
# 2                         10.429637                  0.625000  ...
# 3                         10.475865                  0.639450  ...
# 4                         10.480881                  0.638606  ...
# ...                             ...                       ...  ...
# 8833                       9.149645                  0.550150  ...
# 8834                       9.103004                  0.550483  ...
# 8835                       9.056364                  0.550817  ...
# 8836                       9.009724                  0.551150  ...
# 8837                       8.963083                  0.551483  ...
#
#       MagpieData mean SpaceGroupNumber  MagpieData avg_dev SpaceGroupNumber  \
# 0                            95.178571                            95.061224
# 1                            95.092857                            94.963265
# 2                            95.428571                            95.346939
# 3                            95.092857                            94.963265
# 4                            95.320000                            95.222857
# ...                                ...                                  ...
# 8833                         78.466667                            77.022222
# 8834                         78.466667                            77.022222
# 8835                         78.466667                            77.022222
# 8836                         78.466667                            77.022222
# 8837                         78.466667                            77.022222
#
#       MagpieData mode SpaceGroupNumber  avg s valence electrons  \
# 0                                 12.0                 1.857143
# 1                                 12.0                 1.857143
# 2                                 12.0                 1.857143
# 3                                 12.0                 1.864286
# 4                                 12.0                 1.858571
# ...                                ...                      ...
# 8833                               2.0                 2.000000
# 8834                               2.0                 2.000000
# 8835                               2.0                 2.000000
# 8836                               2.0                 2.000000
# 8837                               2.0                 2.000000
#
#       avg p valence electrons  avg d valence electrons  \
# 0                    2.285714                 1.692857
# 1                    2.285714                 1.692857
# 2                    2.285714                 1.685714
# 3                    2.285714                 1.628571
# 4                    2.285714                 1.675714
# ...                       ...                      ...
# 8833                 2.183333                 0.600000
# 8834                 2.183333                 0.566667
# 8835                 2.183333                 0.533333
# 8836                 2.183333                 0.500000
# 8837                 2.183333                 0.466667
#
#       avg f valence electrons  compound possible  max ionic char  \
# 0                    0.000000              False        0.803211
# 1                    0.000000              False        0.787757
# 2                    3.600000              False        0.803211
# 3                    0.000000              False        0.787757
# 4                    0.000000              False        0.787757
# ...                       ...                ...             ...
# 8833                 4.666667              False        0.348856
# 8834                 4.666667              False        0.348856
# 8835                 4.666667              False        0.348856
# 8836                 4.666667              False        0.348856
# 8837                 4.666667              False        0.348856
#
#       avg ionic char
# 0           0.165284
# 1           0.164994
# 2           0.155938
# 3           0.165653
# 4           0.165292
# ...              ...
# 8833        0.053305
# 8834        0.053562
# 8835        0.053819
# 8836        0.054076
# 8837        0.054332
#
# [8838 rows x 244 columns]
#          Tc
# 0     30.00
# 1     39.00
# 2     71.90
# 3     21.00
# 4     12.00
# ...     ...
# 8833   4.09
# 8834   4.85
# 8835   4.48
# 8836   5.87
# 8837   5.00
#
# [8838 rows x 1 columns]

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42, shuffle=True)

# %% [markdown]
# # Apply normalization to X

# %%
# Normalize train

scaler = StandardScaler()
scaler.fit(X_train)
means_ = scaler.mean_
stds_ = scaler.scale_
norm_train_X = scaler.transform(X_train)

column_names = X_train.columns
norm_train_X = pd.DataFrame(scaler.transform(X_train), columns=column_names)
norm_train_X.columns = norm_train_X.columns.str.replace(' ', '_').str.replace(r'(?<!^)(?=[A-Z])', '_').str.lower()

scaler = StandardScaler()
scaler.fit(X_test)
means_ = scaler.mean_
stds_ = scaler.scale_
norm_test_X = scaler.transform(X_test)

column_names = X_train.columns
norm_test_X = pd.DataFrame(scaler.transform(X_test), columns=column_names)
norm_test_X.columns = norm_test_X.columns.str.replace(' ', '_').str.replace(r'(?<!^)(?=[A-Z])', '_').str.lower()

# %% [markdown]
# # Convert Dataframe to Numpy array

# %%
norm_train_X = norm_train_X.to_numpy() if hasattr(norm_train_X, 'to_numpy') else norm_train_X
norm_test_X = norm_test_X.to_numpy() if hasattr(norm_test_X, 'to_numpy') else norm_test_X
y_train = y_train.to_numpy() if hasattr(y_train, 'to_numpy') else y_train
y_test = y_test.to_numpy() if hasattr(y_test, 'to_numpy') else y_test

# %% [markdown]
# # Define GNN model and parameters

# %%
device = torch.device('cpu')

# Create a KNN graph for your training data
k = 10  # Adjust the number of neighbors
knn_graph_train = kneighbors_graph(norm_train_X, k, mode='connectivity', include_self=True)
edge_index_train = torch.tensor(np.array(knn_graph_train.nonzero()), dtype=torch.long)

knn_graph_test = kneighbors_graph(norm_test_X, k, mode='connectivity', include_self=True)
edge_index_test = torch.tensor(np.array(knn_graph_test.nonzero()), dtype=torch.long)

# Convert your features and labels to tensors
x_train = torch.tensor(norm_train_X, dtype=torch.float).to(device)
y_train = torch.tensor(y_train, dtype=torch.float).view(-1, 1).to(device)
x_test = torch.tensor(norm_test_X, dtype=torch.float).to(device)
y_test = torch.tensor(y_test, dtype=torch.float).view(-1, 1).to(device)

# Create PyTorch Geometric data objects
train_data = Data(x=x_train, edge_index=edge_index_train, y=y_train)
test_data = Data(x=x_test, edge_index=edge_index_test, y=y_test)

# Create data loaders
train_loader = DataLoader([train_data], batch_size=1, shuffle=True)
test_loader = DataLoader([test_data], batch_size=1)

class GNNModel(torch.nn.Module):
    def __init__(self, num_features, hidden_channels, num_layers, dropout_rate):
        super(GNNModel, self).__init__()
        self.convs = torch.nn.ModuleList()
        self.convs.append(GCNConv(num_features, hidden_channels))
        for _ in range(num_layers - 1):
            self.convs.append(GCNConv(hidden_channels, hidden_channels))
        self.lin = torch.nn.Linear(hidden_channels, 1)
        self.dropout_rate = dropout_rate

    def forward(self, x, edge_index):
        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout_rate, training=self.training)
        x = self.lin(x)
        return x
# Out:
# /opt/conda/lib/python3.9/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %% [markdown]
# # Hyperparameter tuning with optuna

# %% [markdown]
# # (Skip this part if already tuned)

# %%
def objective(trial):
    hidden_channels = trial.suggest_int('hidden_channels', 32, 256)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)
    weight_decay = trial.suggest_float('weight_decay', 1e-5, 1e-3, log=True)
    num_layers = trial.suggest_int('num_layers', 2, 5)
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)

    # Initialize model, loss function, and optimizer
    model = GNNModel(num_features=norm_train_X.shape[1], hidden_channels=hidden_channels, num_layers=num_layers, dropout_rate=dropout_rate).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    criterion = torch.nn.MSELoss()

    # Training loop
    model.train()
    for epoch in range(50):  # Increase epochs for better training
        for batch in train_loader:
            optimizer.zero_grad()
            out = model(batch.x, batch.edge_index)
            loss = criterion(out, batch.y)
            loss.backward()
            optimizer.step()

    # Evaluation loop
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in test_loader:
            pred = model(batch.x, batch.edge_index)
            batch_loss = mean_squared_error(batch.y.cpu(), pred.cpu())
            val_loss += batch_loss
        val_loss /= len(test_loader)

    return val_loss

# Run Optuna optimization
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)  # Increase number of trials
# Out:
# [I 2024-05-30 04:17:59,939] A new study created in memory with name: no-name-ac2a122b-eb04-42e1-97c7-3a467dbb696a
# [I 2024-05-30 04:18:11,446] Trial 0 finished with value: 322.15087890625 and parameters: {'hidden_channels': 89, 'learning_rate': 0.0009482559934316206, 'weight_decay': 0.00017171331965491903, 'num_layers': 3, 'dropout_rate': 0.45749029477299963}. Best is trial 0 with value: 322.15087890625.
# [I 2024-05-30 04:18:25,646] Trial 1 finished with value: 288.568603515625 and parameters: {'hidden_channels': 105, 'learning_rate': 0.002061451681107582, 'weight_decay': 0.0004433181500587321, 'num_layers': 3, 'dropout_rate': 0.347556677592114}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:18:53,462] Trial 2 finished with value: 944.7864990234375 and parameters: {'hidden_channels': 206, 'learning_rate': 7.292567009551672e-05, 'weight_decay': 1.945474692174082e-05, 'num_layers': 4, 'dropout_rate': 0.45575344767726256}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:19:18,031] Trial 3 finished with value: 1036.1590576171875 and parameters: {'hidden_channels': 230, 'learning_rate': 3.5429184689296025e-05, 'weight_decay': 1.8211197014488313e-05, 'num_layers': 3, 'dropout_rate': 0.16213320992290134}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:19:46,251] Trial 4 finished with value: 1060.901123046875 and parameters: {'hidden_channels': 129, 'learning_rate': 5.5799765306467164e-05, 'weight_decay': 6.187006643015925e-05, 'num_layers': 5, 'dropout_rate': 0.409598714089077}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:20:11,224] Trial 5 finished with value: 292.2059326171875 and parameters: {'hidden_channels': 116, 'learning_rate': 0.008713564708757426, 'weight_decay': 0.00044265100053654256, 'num_layers': 5, 'dropout_rate': 0.17899503749878318}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:20:43,944] Trial 6 finished with value: 631.8485717773438 and parameters: {'hidden_channels': 155, 'learning_rate': 0.00014246937413563612, 'weight_decay': 0.0002992216220048602, 'num_layers': 5, 'dropout_rate': 0.3104988119480102}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:20:50,243] Trial 7 finished with value: 338.92926025390625 and parameters: {'hidden_channels': 73, 'learning_rate': 0.0012199964093928253, 'weight_decay': 0.0006926090443706686, 'num_layers': 2, 'dropout_rate': 0.4896685475387067}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:20:55,922] Trial 8 finished with value: 765.788330078125 and parameters: {'hidden_channels': 62, 'learning_rate': 0.0004246789869789632, 'weight_decay': 0.0005066259639004232, 'num_layers': 2, 'dropout_rate': 0.2880228927602668}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:21:23,222] Trial 9 finished with value: 483.9848937988281 and parameters: {'hidden_channels': 144, 'learning_rate': 0.00017633026485449076, 'weight_decay': 0.00029766958071155954, 'num_layers': 5, 'dropout_rate': 0.43416624991801434}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:21:31,543] Trial 10 finished with value: 1088.9371337890625 and parameters: {'hidden_channels': 36, 'learning_rate': 1.107366324631855e-05, 'weight_decay': 7.233350168166689e-05, 'num_layers': 4, 'dropout_rate': 0.33010146757855585}. Best is trial 1 with value: 288.568603515625.
# [I 2024-05-30 04:21:42,537] Trial 11 finished with value: 248.8866729736328 and parameters: {'hidden_channels': 114, 'learning_rate': 0.00990806342700634, 'weight_decay': 0.0009038248027701706, 'num_layers': 3, 'dropout_rate': 0.1250556562815271}. Best is trial 11 with value: 248.8866729736328.
# [I 2024-05-30 04:21:58,645] Trial 12 finished with value: 269.370849609375 and parameters: {'hidden_channels': 165, 'learning_rate': 0.009766477187309964, 'weight_decay': 0.0008265187964355723, 'num_layers': 3, 'dropout_rate': 0.11175415073509445}. Best is trial 11 with value: 248.8866729736328.
# [I 2024-05-30 04:22:17,841] Trial 13 finished with value: 262.3080749511719 and parameters: {'hidden_channels': 178, 'learning_rate': 0.009298540312685157, 'weight_decay': 0.0009784054220547066, 'num_layers': 3, 'dropout_rate': 0.10492709249760493}. Best is trial 11 with value: 248.8866729736328.
# [I 2024-05-30 04:22:31,836] Trial 14 finished with value: 247.10122680664062 and parameters: {'hidden_channels': 186, 'learning_rate': 0.003113716347863696, 'weight_decay': 0.0009709922299177028, 'num_layers': 2, 'dropout_rate': 0.22284732427129458}. Best is trial 14 with value: 247.10122680664062.
# [I 2024-05-30 04:22:47,649] Trial 15 finished with value: 234.91812133789062 and parameters: {'hidden_channels': 252, 'learning_rate': 0.003475549921893372, 'weight_decay': 0.00016530203926159567, 'num_layers': 2, 'dropout_rate': 0.22218251664861413}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:23:01,930] Trial 16 finished with value: 251.3098907470703 and parameters: {'hidden_channels': 256, 'learning_rate': 0.003070316456328158, 'weight_decay': 3.7463866343376416e-05, 'num_layers': 2, 'dropout_rate': 0.23883767674742878}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:23:14,248] Trial 17 finished with value: 238.69964599609375 and parameters: {'hidden_channels': 198, 'learning_rate': 0.0037142840961489317, 'weight_decay': 0.00015384219951865955, 'num_layers': 2, 'dropout_rate': 0.2432981551748468}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:23:29,731] Trial 18 finished with value: 332.6859436035156 and parameters: {'hidden_channels': 248, 'learning_rate': 0.0005463393639850557, 'weight_decay': 0.00015114207312121126, 'num_layers': 2, 'dropout_rate': 0.25453202037605444}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:23:57,739] Trial 19 finished with value: 282.9285888671875 and parameters: {'hidden_channels': 218, 'learning_rate': 0.003812956056550554, 'weight_decay': 0.00013385946339030026, 'num_layers': 4, 'dropout_rate': 0.20700537353838533}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:24:10,260] Trial 20 finished with value: 274.5911560058594 and parameters: {'hidden_channels': 200, 'learning_rate': 0.001018018344381771, 'weight_decay': 4.059287539069694e-05, 'num_layers': 2, 'dropout_rate': 0.38331774416993514}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:24:22,721] Trial 21 finished with value: 248.39260864257812 and parameters: {'hidden_channels': 184, 'learning_rate': 0.0036199164335403724, 'weight_decay': 0.0002372182587801866, 'num_layers': 2, 'dropout_rate': 0.25383543144093085}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:24:38,151] Trial 22 finished with value: 252.76986694335938 and parameters: {'hidden_channels': 233, 'learning_rate': 0.0021956352832280678, 'weight_decay': 8.728972928105336e-05, 'num_layers': 2, 'dropout_rate': 0.2050926248730284}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:24:50,826] Trial 23 finished with value: 236.57757568359375 and parameters: {'hidden_channels': 186, 'learning_rate': 0.004488535826115772, 'weight_decay': 0.0002043841587054324, 'num_layers': 2, 'dropout_rate': 0.2775940004107056}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:25:04,351] Trial 24 finished with value: 240.0423126220703 and parameters: {'hidden_channels': 203, 'learning_rate': 0.0048358050021025745, 'weight_decay': 0.00011918791970108459, 'num_layers': 2, 'dropout_rate': 0.2817743854602937}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:25:18,460] Trial 25 finished with value: 252.4463348388672 and parameters: {'hidden_channels': 232, 'learning_rate': 0.0016640888557838398, 'weight_decay': 0.00021427843261583198, 'num_layers': 2, 'dropout_rate': 0.17078700631645083}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:25:34,321] Trial 26 finished with value: 250.97174072265625 and parameters: {'hidden_channels': 166, 'learning_rate': 0.005290392299044804, 'weight_decay': 1.0775671563807684e-05, 'num_layers': 3, 'dropout_rate': 0.2692078549840988}. Best is trial 15 with value: 234.91812133789062.
# [I 2024-05-30 04:25:48,631] Trial 27 finished with value: 231.24720764160156 and parameters: {'hidden_channels': 217, 'learning_rate': 0.005731263506206205, 'weight_decay': 0.00010686021668819513, 'num_layers': 2, 'dropout_rate': 0.3425592929785849}. Best is trial 27 with value: 231.24720764160156.
# [I 2024-05-30 04:26:09,432] Trial 28 finished with value: 299.2892150878906 and parameters: {'hidden_channels': 217, 'learning_rate': 0.0005830744719066719, 'weight_decay': 5.7951722088436524e-05, 'num_layers': 3, 'dropout_rate': 0.355286190555227}. Best is trial 27 with value: 231.24720764160156.
# [I 2024-05-30 04:26:24,335] Trial 29 finished with value: 277.7347717285156 and parameters: {'hidden_channels': 237, 'learning_rate': 0.0008342030781506742, 'weight_decay': 9.910559278162742e-05, 'num_layers': 2, 'dropout_rate': 0.31790203460194916}. Best is trial 27 with value: 231.24720764160156.
# [I 2024-05-30 04:26:52,848] Trial 30 finished with value: 267.5850524902344 and parameters: {'hidden_channels': 218, 'learning_rate': 0.005628806569728626, 'weight_decay': 0.00020722157044759574, 'num_layers': 4, 'dropout_rate': 0.3811292737270874}. Best is trial 27 with value: 231.24720764160156.
# [I 2024-05-30 04:27:06,131] Trial 31 finished with value: 250.0270538330078 and parameters: {'hidden_channels': 194, 'learning_rate': 0.001976807560188363, 'weight_decay': 0.0001420709817259928, 'num_layers': 2, 'dropout_rate': 0.29567224196846176}. Best is trial 27 with value: 231.24720764160156.
# [I 2024-05-30 04:27:22,024] Trial 32 finished with value: 230.44259643554688 and parameters: {'hidden_channels': 245, 'learning_rate': 0.005546279822622149, 'weight_decay': 0.00017951390953999048, 'num_layers': 2, 'dropout_rate': 0.2227368731210766}. Best is trial 32 with value: 230.44259643554688.
# [I 2024-05-30 04:27:44,821] Trial 33 finished with value: 257.802490234375 and parameters: {'hidden_channels': 249, 'learning_rate': 0.006359980473143009, 'weight_decay': 0.0003277197100534418, 'num_layers': 3, 'dropout_rate': 0.3444857850276737}. Best is trial 32 with value: 230.44259643554688.
# [I 2024-05-30 04:27:57,822] Trial 34 finished with value: 246.3528289794922 and parameters: {'hidden_channels': 242, 'learning_rate': 0.0015344987201230513, 'weight_decay': 0.0001914219079250246, 'num_layers': 2, 'dropout_rate': 0.19359579425641935}. Best is trial 32 with value: 230.44259643554688.
# [I 2024-05-30 04:28:17,028] Trial 35 finished with value: 260.2232971191406 and parameters: {'hidden_channels': 220, 'learning_rate': 0.002607014251522664, 'weight_decay': 9.995111536342033e-05, 'num_layers': 3, 'dropout_rate': 0.22056742268793322}. Best is trial 32 with value: 230.44259643554688.
# [I 2024-05-30 04:28:29,442] Trial 36 finished with value: 228.56539916992188 and parameters: {'hidden_channels': 213, 'learning_rate': 0.006403038339841934, 'weight_decay': 0.0003698199248177559, 'num_layers': 2, 'dropout_rate': 0.14896184865809967}. Best is trial 36 with value: 228.56539916992188.
# [I 2024-05-30 04:28:43,541] Trial 37 finished with value: 234.83274841308594 and parameters: {'hidden_channels': 255, 'learning_rate': 0.006909171568870013, 'weight_decay': 0.0003903240917307317, 'num_layers': 2, 'dropout_rate': 0.14457109577057398}. Best is trial 36 with value: 228.56539916992188.
# [I 2024-05-30 04:29:04,026] Trial 38 finished with value: 264.0904846191406 and parameters: {'hidden_channels': 224, 'learning_rate': 0.00655583043833335, 'weight_decay': 0.0005502816459341719, 'num_layers': 3, 'dropout_rate': 0.1283126131451187}. Best is trial 36 with value: 228.56539916992188.
# [I 2024-05-30 04:29:17,346] Trial 39 finished with value: 658.8527221679688 and parameters: {'hidden_channels': 211, 'learning_rate': 0.00020557378446884025, 'weight_decay': 0.00038103698322794564, 'num_layers': 2, 'dropout_rate': 0.15945969423966788}. Best is trial 36 with value: 228.56539916992188.
# [I 2024-05-30 04:29:31,043] Trial 40 finished with value: 234.80661010742188 and parameters: {'hidden_channels': 241, 'learning_rate': 0.0071900632012363574, 'weight_decay': 0.0006359902708754205, 'num_layers': 2, 'dropout_rate': 0.155396261706973}. Best is trial 36 with value: 228.56539916992188.
# [I 2024-05-30 04:29:45,525] Trial 41 finished with value: 228.5673828125 and parameters: {'hidden_channels': 241, 'learning_rate': 0.006017754852439442, 'weight_decay': 0.0006103332792216647, 'num_layers': 2, 'dropout_rate': 0.15040314191868542}. Best is trial 36 with value: 228.56539916992188.
# [I 2024-05-30 04:30:00,533] Trial 42 finished with value: 222.95181274414062 and parameters: {'hidden_channels': 239, 'learning_rate': 0.007092419543561266, 'weight_decay': 0.0006617145213958432, 'num_layers': 2, 'dropout_rate': 0.1493314224830723}. Best is trial 42 with value: 222.95181274414062.
# [I 2024-05-30 04:30:15,940] Trial 43 finished with value: 243.8135223388672 and parameters: {'hidden_channels': 229, 'learning_rate': 0.0024004331915921597, 'weight_decay': 0.000638426194856133, 'num_layers': 2, 'dropout_rate': 0.18427200631286755}. Best is trial 42 with value: 222.95181274414062.
# [I 2024-05-30 04:30:30,031] Trial 44 finished with value: 1030.3780517578125 and parameters: {'hidden_channels': 210, 'learning_rate': 3.488267950926548e-05, 'weight_decay': 0.00043225726162082073, 'num_layers': 2, 'dropout_rate': 0.1480738680795639}. Best is trial 42 with value: 222.95181274414062.
# [I 2024-05-30 04:30:40,953] Trial 45 finished with value: 242.41183471679688 and parameters: {'hidden_channels': 136, 'learning_rate': 0.007593810738443995, 'weight_decay': 0.00028502254309612277, 'num_layers': 2, 'dropout_rate': 0.1302868867262687}. Best is trial 42 with value: 222.95181274414062.
# [I 2024-05-30 04:31:04,549] Trial 46 finished with value: 261.90924072265625 and parameters: {'hidden_channels': 241, 'learning_rate': 0.0013758338511245772, 'weight_decay': 0.0002630174287252204, 'num_layers': 3, 'dropout_rate': 0.1753206041011246}. Best is trial 42 with value: 222.95181274414062.
# [I 2024-05-30 04:31:27,421] Trial 47 finished with value: 251.91351318359375 and parameters: {'hidden_channels': 228, 'learning_rate': 0.004652523341544965, 'weight_decay': 0.0005168359810727825, 'num_layers': 3, 'dropout_rate': 0.10795085869351839}. Best is trial 42 with value: 222.95181274414062.
# [I 2024-05-30 04:31:39,936] Trial 48 finished with value: 231.96630859375 and parameters: {'hidden_channels': 172, 'learning_rate': 0.00988925162193125, 'weight_decay': 0.000772942243397054, 'num_layers': 2, 'dropout_rate': 0.13173510065898397}. Best is trial 42 with value: 222.95181274414062.
# [I 2024-05-30 04:32:09,531] Trial 49 finished with value: 813.2684936523438 and parameters: {'hidden_channels': 149, 'learning_rate': 0.00010271170051454733, 'weight_decay': 0.00035418849812975795, 'num_layers': 5, 'dropout_rate': 0.19695906484928025}. Best is trial 42 with value: 222.95181274414062.

# %% [markdown]
# # Training the final model with best hyperparameters

# %%
best_params = study.best_params
print(best_params)

# Initialize the model with the best hyperparameters found
model = GNNModel(num_features=norm_train_X.shape[1], hidden_channels=best_params['hidden_channels'], num_layers=best_params['num_layers'], dropout_rate=best_params['dropout_rate']).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=best_params['learning_rate'], weight_decay=best_params['weight_decay'])
criterion = torch.nn.MSELoss()

# Training loop with the best hyperparameters and more epochs
model.train()
for epoch in range(100):  # Increased number of epochs
    for batch in train_loader:
        optimizer.zero_grad()
        out = model(batch.x, batch.edge_index)
        loss = criterion(out, batch.y)
        loss.backward()
        optimizer.step()
        
# Save the model
torch.save(model.state_dict(), 'gnn_model.pth')
# Out:
# {'hidden_channels': 239, 'learning_rate': 0.007092419543561266, 'weight_decay': 0.0006617145213958432, 'num_layers': 2, 'dropout_rate': 0.1493314224830723}

# %%
# Predictions
model.eval()
with torch.no_grad():
    pred_train_y = model(x_train, edge_index_train).cpu().numpy()
    pred_test_y = model(x_test, edge_index_test).cpu().numpy()

# %%
# Calculate metrics for train data
mae_train = mean_absolute_error(y_train.cpu().numpy(), pred_train_y)
rmse_train = mean_squared_error(y_train.cpu().numpy(), pred_train_y, squared=False)
mse_train = mean_squared_error(y_train.cpu().numpy(), pred_train_y, squared=True)
r2_train = r2_score(y_train.cpu().numpy(), pred_train_y)

# Calculate metrics for test data
mae_test = mean_absolute_error(y_test.cpu().numpy(), pred_test_y)
rmse_test = mean_squared_error(y_test.cpu().numpy(), pred_test_y, squared=False)
mse_test = mean_squared_error(y_test.cpu().numpy(), pred_test_y, squared=True)
r2_test = r2_score(y_test.cpu().numpy(), pred_test_y)

# Plot results for train data
fig, ax = plt.subplots(figsize=(12, 8))
plt.plot(y_train.cpu().numpy(), pred_train_y, "bx", label="Train Data")
plt.xlabel("Actual Tc (K)")
plt.ylabel("Predicted Tc (K)")
plt.title("GNN Regression Train")
plt.plot([min(y_train.cpu().numpy()), max(y_train.cpu().numpy())], 
         [min(y_train.cpu().numpy()), max(y_train.cpu().numpy())], "k--", linewidth=2)
plt.annotate(f"Train MAE = {mae_train:.5f} K\nTrain RMSE = {rmse_train:.5f} K\nTrain MSE = {mse_train:.8f} K\nTrain R² = {r2_train:.2f}", 
             (0.05, 0.95), xycoords="axes fraction", fontsize=14, 
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))
plt.legend()
plt.show()

# Plot results for test data
fig, ax = plt.subplots(figsize=(12, 8))
plt.plot(y_test.cpu().numpy(), pred_test_y, "rx", label="Test Data")
plt.xlabel("Actual Tc (K)")
plt.ylabel("Predicted Tc (K)")
plt.title("GNN Regression Test")
plt.plot([min(y_test.cpu().numpy()), max(y_test.cpu().numpy())], 
         [min(y_test.cpu().numpy()), max(y_test.cpu().numpy())], "k--", linewidth=2)
plt.annotate(f"Test MAE = {mae_test:.5f} K\nTest RMSE = {rmse_test:.5f} K\nTest MSE = {mse_test:.8f} K\nTest R² = {r2_test:.2f}", 
             (0.05, 0.95), xycoords="axes fraction", fontsize=14, 
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))
plt.legend()
plt.show()

# %%
# Function to calculate feature importance
def calculate_feature_importance(model, data, edge_index, device):
    model.eval()
    baseline_pred = model(data, edge_index).cpu().detach().numpy().flatten()
    
    feature_importances = np.zeros(data.shape[1])
    for i in range(data.shape[1]):
        data_perturbed = data.clone().cpu().detach().numpy()
        data_perturbed[:, i] = 0  # Zero out the i-th feature
        data_perturbed = torch.tensor(data_perturbed, dtype=torch.float).to(device)
        
        with torch.no_grad():
            perturbed_pred = model(data_perturbed, edge_index).cpu().detach().numpy().flatten()
        
        feature_importances[i] = np.mean(np.abs(baseline_pred - perturbed_pred))
    
    return feature_importances

# Calculate feature importance for train data
x_train = torch.tensor(norm_train_X, dtype=torch.float).to(device)
feature_importances = calculate_feature_importance(model, x_train, edge_index_train, device)

# Get feature names from the original DataFrame
feature_names = X.columns if hasattr(X, 'columns') else [f'Feature {i}' for i in range(norm_train_X.shape[1])]

# Create a DataFrame for feature importances
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
})

# Sort by importance and select top 20 features
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).head(100)

# Plot feature importances
plt.figure(figsize=(12, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.title('Top 20 Feature Importances in GNN')
plt.gca().invert_yaxis()
plt.show()
